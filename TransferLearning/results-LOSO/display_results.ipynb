# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
sns.set_theme()

# %%
files = [file for file in os.listdir(".\\") if file.endswith(".csv")]

# %%
data_list = {}
df = pd.DataFrame([])
for file in files:
    data = pd.read_csv(file)
    data_list[file] = data
    df = pd.concat([df, pd.DataFrame([data["accuracy"].mean(), data["recall"].mean(), data["precision"].mean(), data["f1"].mean(), data["max epoch"].mean()]).T.rename(columns={0: "acc", 1: "recall", 2: "precision", 3: "f1", 4: "epochs"}, index={0: file[:-4].replace("_", " ")})])
df.sort_values(by=['acc'], ascending=False)
# Out:
#                                      acc    recall  precision        f1  \
# intense model all              77.914167  0.804193   0.804193  0.804193
# intense                        77.884167  0.808422   0.808422  0.808422
# intense model tonic heat       77.605417  0.805928   0.805928  0.805928
# intense model tonic electric   77.088750  0.795243   0.795243  0.795243
# intense model electric         76.696250  0.794163   0.794163  0.794163
# intense model heat             76.652500  0.802170   0.802170  0.802170
# intense model phasic electric  76.488750  0.792924   0.792924  0.792924
# intense model tonic            76.453750  0.797352   0.797352  0.797352
# intense model phasic           75.725833  0.786376   0.786376  0.786376
# intense model phasic heat      75.170833  0.775410   0.775410  0.775410
#
#                                   epochs
# intense model all              11.500000
# intense                        12.083333
# intense model tonic heat       12.500000
# intense model tonic electric   14.333333
# intense model electric         15.333333
# intense model heat             13.333333
# intense model phasic electric  14.583333
# intense model tonic            17.291667
# intense model phasic           14.791667
# intense model phasic heat      12.250000

# %%
data_list["intense_model_all.csv"]["accuracy"].plot.kde()
data_list["intense_model_electric.csv"]["accuracy"].plot.kde()
data_list["intense_model_heat.csv"]["accuracy"].plot.kde()
data_list["intense.csv"]["accuracy"].plot.kde()
plt.legend(["all model", "electric model", "heat model", "no model"])
plt.title("Accuracy Classification INTENSE")
plt.show()
