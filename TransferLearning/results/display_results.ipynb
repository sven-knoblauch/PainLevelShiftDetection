# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
sns.set_theme()

# %%
files = [file for file in os.listdir(".\\") if file.endswith(".csv")]
files = files[:-1]

# %%
data_list = {}
df = pd.DataFrame([])
for file in files:
    data = pd.read_csv(file)
    data_list[file] = data
    df = pd.concat([df, pd.DataFrame([data["accuracy"].mean(), data["recall"].mean(), data["precision"].mean(), data["f1"].mean(), data["max epoch"].mean()]).T.rename(columns={0: "acc", 1: "recall", 2: "precision", 3: "f1", 4: "epochs"}, index={0: file[:-4].replace("_", " ")})])
df
# Out:
#                                              acc    recall  precision  \
# 10 fold intense                        74.507000  0.765656   0.765656
# 10 fold intense model all              74.566000  0.773331   0.773331
# 10 fold intense model all2             74.149000  0.760654   0.760654
# 10 fold intense model electric         74.774000  0.769447   0.769447
# 10 fold intense model heat             67.880000  0.707713   0.707713
# 10 fold intense model phasic           69.778000  0.722849   0.722849
# 10 fold intense model phasic electric  73.970000  0.766767   0.766767
# 10 fold intense model phasic heat      68.200000  0.696739   0.696739
# 10 fold intense model tonic            74.790000  0.770675   0.770675
# 10 fold intense model tonic electric   69.722000  0.719379   0.719379
# 10 fold intense model tonic heat       66.417000  0.682330   0.682330
# LOSO intense                           76.570000  0.792886   0.792886
# LOSO intense model all                 75.330417  0.781767   0.781767
#
#                                              f1     epochs
# 10 fold intense                        0.765656  17.400000
# 10 fold intense model all              0.773331  19.000000
# 10 fold intense model all2             0.760654  18.400000
# 10 fold intense model electric         0.769447  16.400000
# 10 fold intense model heat             0.707713  16.200000
# 10 fold intense model phasic           0.722849  15.300000
# 10 fold intense model phasic electric  0.766767  19.700000
# 10 fold intense model phasic heat      0.696739  15.800000
# 10 fold intense model tonic            0.770675  16.200000
# 10 fold intense model tonic electric   0.719379  20.800000
# 10 fold intense model tonic heat       0.682330  14.800000
# LOSO intense                           0.792886  12.125000
# LOSO intense model all                 0.781767  16.041667

# %%
data_list["10_fold_intense_model_all.csv"]["accuracy"].plot.kde()
data_list["10_fold_intense.csv"]["accuracy"].plot.kde()
plt.legend(["with model", "no model"])
plt.title("Accuracy Classification INTENSE")
plt.show()
